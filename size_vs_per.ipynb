# %%
import numpy as np
import pandas as pd

data = pd.read_csv("/home/chaithanya/Downloads/planets.csv", skiprows=71)

# %%
data.columns
# Out:
# Index(['loc_rowid', 'pl_hostname', 'pl_letter', 'pl_name', 'pl_discmethod',
#        'pl_pnum', 'pl_orbper', 'pl_orbpererr1', 'pl_orbpererr2',
#        'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1', 'pl_orbsmaxerr2',
#        'pl_orbsmaxlim', 'pl_orbeccen', 'pl_orbeccenerr1', 'pl_orbeccenerr2',
#        'pl_orbeccenlim', 'pl_orbincl', 'pl_orbinclerr1', 'pl_orbinclerr2',
#        'pl_orbincllim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_dens', 'pl_denserr1', 'pl_denserr2', 'pl_denslim',
#        'pl_ttvflag', 'pl_kepflag', 'pl_k2flag', 'pl_nnotes', 'ra_str', 'ra',
#        'dec_str', 'dec', 'st_dist', 'st_disterr1', 'st_disterr2', 'st_distlim',
#        'st_optmag', 'st_optmagerr', 'st_optmaglim', 'st_optband', 'gaia_gmag',
#        'gaia_gmagerr', 'gaia_gmaglim', 'st_teff', 'st_tefferr1', 'st_tefferr2',
#        'st_tefflim', 'st_mass', 'st_masserr1', 'st_masserr2', 'st_masslim',
#        'st_rad', 'st_raderr1', 'st_raderr2', 'st_radlim', 'rowupdate',
#        'pl_facility'],
#       dtype='object')

# %%
df1 = data[['pl_name','pl_pnum', 'pl_orbper', 'pl_radj']]
grp=df1.groupby('pl_pnum')

# %%
pl_1  =grp.get_group(1)
pl_2  =grp.get_group(2)
pl_3  =grp.get_group(3)
pl_2  =grp.get_group(2)
pl_4  =grp.get_group(4)
pl_5  =grp.get_group(5)
pl_6  =grp.get_group(6)
pl_7  =grp.get_group(7)

# %%
ax1 = pl_1.plot(x='pl_orbper', y='pl_radj' , color='r', kind='scatter', label='pnum=1', logx =True)
ax2 = pl_2.plot(x='pl_orbper', y='pl_radj' , color='b' , kind='scatter', label='pnum=2', ax=ax1, logx=True)
ax3 = pl_3.plot(x='pl_orbper', y='pl_radj' , color='g' , kind='scatter', label='pnum=3', ax=ax1, logx =True)
ax4 = pl_4.plot(x='pl_orbper', y='pl_radj' , color='c' , kind='scatter', label='pnum=4', ax=ax1, logx =True)
ax5 = pl_5.plot(x='pl_orbper', y='pl_radj' , color='k' , kind='scatter', label='pnum=5', ax=ax1, logx =True)
ax6 = pl_6.plot(x='pl_orbper', y='pl_radj' , color='m' , kind='scatter', label='pnum=6', ax=ax1, logx =True)
ax7 = pl_7.plot(x='pl_orbper', y='pl_radj' , color='y' , kind='scatter', label='pnum=7', ax=ax1, logx =True)
ax1.set_xlabel("orbital period in days")
ax1.set_ylabel("planet radius compared to jupiter")
# Out:
# Text(0,0.5,'planet radius compared to jupiter')

# %%
ax1 = pl_1.plot(x='pl_orbper', y='pl_radj' , color='r', kind='scatter', label='pnum=1', xlim=(0,700))
ax2 = pl_2.plot(x='pl_orbper', y='pl_radj' , color='b' , kind='scatter', label='pnum=2', ax=ax1)
ax3 = pl_3.plot(x='pl_orbper', y='pl_radj' , color='g' , kind='scatter', label='pnum=3', ax=ax1)
ax4 = pl_4.plot(x='pl_orbper', y='pl_radj' , color='c' , kind='scatter', label='pnum=4', ax=ax1)
ax5 = pl_5.plot(x='pl_orbper', y='pl_radj' , color='k' , kind='scatter', label='pnum=5', ax=ax1)
ax6 = pl_6.plot(x='pl_orbper', y='pl_radj' , color='m' , kind='scatter', label='pnum=6', ax=ax1)
ax7 = pl_7.plot(x='pl_orbper', y='pl_radj' , color='y' , kind='scatter', label='pnum=7', ax=ax1)

# %%
ax1 = pl_1.plot(x='pl_orbper', y='pl_radj' , color='r', kind='scatter', label='pnum=1', logx =True)
ax2 = pl_2.plot(x='pl_orbper', y='pl_radj' , color='b' , kind='scatter', label='pnum=2', logx =True)
ax3 = pl_3.plot(x='pl_orbper', y='pl_radj' , color='g' , kind='scatter', label='pnum=3', logx =True)
ax4 = pl_4.plot(x='pl_orbper', y='pl_radj' , color='c' , kind='scatter', label='pnum=4', logx =True)
ax5 = pl_5.plot(x='pl_orbper', y='pl_radj' , color='k' , kind='scatter', label='pnum=5', logx =True)
ax6 = pl_6.plot(x='pl_orbper', y='pl_radj' , color='m' , kind='scatter', label='pnum=6', logx =True)
ax7 = pl_7.plot(x='pl_orbper', y='pl_radj' , color='y' , kind='scatter', label='pnum=7', logx =True)
