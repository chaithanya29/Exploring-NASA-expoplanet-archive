# %%
import pandas as pd
df = pd.read_csv("/home/chaithanya/Downloads/planets2.csv", skiprows =35)

# %%
df.to_csv('/home/chaithanya/Downloads/planets1.csv')

# %%
gaia_exo = pd.read_csv("/home/chaithanya/Downloads/gaia_exo_full.csv")
# Out:
# /home/chaithanya/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2=gaia_exo[['phot_g_mean_mag', 'gaia_gmag']].round(1)

# %%
df2
# Out:
#       phot_g_mean_mag  gaia_gmag
# 0                 4.4        4.4
# 1                 4.5        4.5
# 2                 4.9        4.9
# 3                 6.1        6.1
# 4                 5.2        5.2
# 5                20.0       12.1
# 6                12.1       12.1
# 7                 5.3        5.3
# 8                 6.2        6.2
# 9                 6.2        6.2
# 10               12.9       12.9
# 11               15.0       15.0
# 12               21.0       15.0
# 13               19.0       19.0
# 14               17.4       17.4
# 15               12.1       12.1
# 16               17.4       17.4
# 17               11.9       11.9
# 18                7.0        7.0
# 19                4.2        4.2
# 20                4.4        4.4
# 21                5.1        5.1
# 22                5.3        5.3
# 23                3.6        3.6
# 24                5.1        5.1
# 25                6.6        6.6
# 26                5.3        5.3
# ...

# %%
anomaly=pd.DataFrame([])
for i in range(len(df2)):
    if (df2.iloc[i,0]!= df2.iloc[i,1]):
        anomaly=anomaly.append(gaia_exo.iloc[i,:])

# %%
ind=list(anomaly.index)

# %%
anomaly
# Out:
#       a_g_percentile_lower  a_g_percentile_upper  a_g_val   angdist  \
# 5                      NaN                   NaN      NaN  0.001230
# 12                     NaN                   NaN      NaN  0.001343
# 41                     NaN                   NaN      NaN  0.001109
# 47                  0.6710                1.1385   0.8887  0.000657
# 52                     NaN                   NaN      NaN  0.000687
# 57                     NaN                   NaN      NaN  0.001183
# 61                     NaN                   NaN      NaN  0.000965
# 62                     NaN                   NaN      NaN  0.001283
# 65                     NaN                   NaN      NaN  0.001042
# 72                     NaN                   NaN      NaN  0.000753
# 73                     NaN                   NaN      NaN  0.000711
# 75                     NaN                   NaN      NaN  0.000814
# 80                     NaN                   NaN      NaN  0.001381
# ...

# %%
gaia_exo.drop(ind, axis=0, inplace=True)

# %%
list(gaia_exo.columns)
# Out:
# ['solution_id',
#  'designation',
#  'source_id',
#  'random_index',
#  'ref_epoch',
#  'ra',
#  'ra_error',
#  'dec',
#  'dec_error',
#  'parallax',
#  'parallax_error',
#  'parallax_over_error',
#  'pmra',
#  'pmra_error',
#  'pmdec',
#  'pmdec_error',
#  'ra_dec_corr',
#  'ra_parallax_corr',
#  'ra_pmra_corr',
#  'ra_pmdec_corr',
#  'dec_parallax_corr',
#  'dec_pmra_corr',
#  'dec_pmdec_corr',
#  'parallax_pmra_corr',
#  'parallax_pmdec_corr',
#  'pmra_pmdec_corr',
#  'astrometric_n_obs_al',
#  'astrometric_n_obs_ac',
#  'astrometric_n_good_obs_al',
#  'astrometric_n_bad_obs_al',
#  'astrometric_gof_al',
#  'astrometric_chi2_al',
#  'astrometric_excess_noise',
#  'astrometric_excess_noise_sig',
#  'astrometric_params_solved',
#  'astrometric_primary_flag',
#  'astrometric_weight_al',
#  'astrometric_pseudo_colour',
#  'astrometric_pseudo_colour_error',
#  'mean_varpi_factor_al',
#  'astrometric_matched_observations',
#  'visibility_periods_used',
#  'astrometric_sigma5d_max',
# ...

# %%
gaia_exo.drop(['parallax_over_error','ra_dec_corr',
 'ra_parallax_corr','phot_bp_n_obs','phot_bp_rp_excess_factor',
 'phot_proc_mode',
 'bp_rp','priam_flags',
 'bp_g','rv_nb_transits',
 'teff_percentile_lower',
 'teff_percentile_upper',
 'a_g_val','epoch_photometry_url',
 'a_g_percentile_lower',
 'a_g_percentile_upper',
 'e_bp_min_rp_val',
 'e_bp_min_rp_percentile_lower',
 'e_bp_min_rp_percentile_upper',
 'flame_flags',
 'rv_template_teff',
 'rv_template_logg',
 'rv_template_fe_h',
 'phot_variable_flag',
 'g_rp',
 'ra_pmra_corr',
 'ra_pmdec_corr',
 'dec_parallax_corr',
 'dec_pmra_corr',
 'dec_pmdec_corr',
 'parallax_pmra_corr',
 'parallax_pmdec_corr',
 'pmra_pmdec_corr',
 'astrometric_n_obs_al',
 'astrometric_n_obs_ac',
 'astrometric_n_good_obs_al',
 'astrometric_n_bad_obs_al',
 'astrometric_gof_al',
 'astrometric_chi2_al',
 'astrometric_excess_noise',
 'astrometric_excess_noise_sig',
 'astrometric_params_solved',
 'astrometric_primary_flag',
 'astrometric_weight_al',
 'astrometric_pseudo_colour',
 'astrometric_pseudo_colour_error',
 'mean_varpi_factor_al',
 'astrometric_matched_observations',
 'visibility_periods_used',
 'astrometric_sigma5d_max',
 'frame_rotator_object_type',
 'matched_observations',
 'duplicated_source',
 'phot_g_n_obs',], axis=1, inplace=True)

# %%
list(gaia_exo.columns)
# Out:
# ['solution_id',
#  'designation',
#  'source_id',
#  'random_index',
#  'ref_epoch',
#  'ra',
#  'ra_error',
#  'dec',
#  'dec_error',
#  'parallax',
#  'parallax_error',
#  'pmra',
#  'pmra_error',
#  'pmdec',
#  'pmdec_error',
#  'phot_g_mean_flux',
#  'phot_g_mean_flux_error',
#  'phot_g_mean_flux_over_error',
#  'phot_g_mean_mag',
#  'phot_bp_mean_flux',
#  'phot_bp_mean_flux_error',
#  'phot_bp_mean_flux_over_error',
#  'phot_bp_mean_mag',
#  'phot_rp_n_obs',
#  'phot_rp_mean_flux',
#  'phot_rp_mean_flux_error',
#  'phot_rp_mean_flux_over_error',
#  'phot_rp_mean_mag',
#  'radial_velocity',
#  'radial_velocity_error',
#  'l',
#  'b',
#  'ecl_lon',
#  'ecl_lat',
#  'teff_val',
#  'radius_val',
#  'radius_percentile_lower',
#  'radius_percentile_upper',
#  'lum_val',
#  'lum_percentile_lower',
#  'lum_percentile_upper',
#  'datalink_url',
#  'exo_oid',
#  'col1',
#  'loc_rowid',
#  'pl_hostname',
#  'pl_letter',
#  'pl_name',
#  'pl_discmethod',
#  'pl_pnum',
#  'pl_orbper',
# ...

# %%
gaia_exo.to_csv("/home/chaithanya/gaia_exo.csv")

# %%
import numpy as np

# %%
df4=np.log(gaia_exo['lum_val'])

# %%
gaia_exo=pd.concat([gaia_exo, df4], axis=1)

# %%
gaia_exo.columns=['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch',
       'ra', 'ra_error', 'dec', 'dec_error', 'parallax', 'parallax_error',
       'pmra', 'pmra_error', 'pmdec', 'pmdec_error', 'phot_g_mean_flux',
       'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error',
       'phot_g_mean_mag', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error',
       'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs',
       'phot_rp_mean_flux', 'phot_rp_mean_flux_error',
       'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'radial_velocity',
       'radial_velocity_error', 'l', 'b', 'ecl_lon', 'ecl_lat','teff_val', 'radius_val',
       'radius_percentile_lower', 'radius_percentile_upper', 'lum_val',
       'lum_percentile_lower', 'lum_percentile_upper', 'datalink_url',
       'exo_oid', 'col1', 'loc_rowid', 'pl_hostname', 'pl_letter', 'pl_name',
       'pl_discmethod', 'pl_pnum', 'pl_orbper', 'pl_orbsmax', 'pl_orbeccen',
       'pl_orbincl', 'pl_bmassj', 'pl_bmassprov', 'pl_radj', 'pl_dens',
       'ra_str', 'ra.1', 'dec_str', 'dec.1', 'st_dist', 'st_optmag',
       'st_optband', 'gaia_gmag', 'st_teff', 'st_mass', 'st_rad',
       'pl_facility', 'st_rah', 'st_glon', 'st_glat', 'st_plx', 'st_radv',
       'st_lum', 'angdist', 'log_lum_val']

# %%
diff_blum = -2.5*(gaia_exo['log_lum_val']-gaia_exo['st_lum'])/gaia_exo['log_lum_val']

# %%
diff_rad = (gaia_exo['radius_val']-gaia_exo['st_rad'])/gaia_exo['radius_val']

# %%
diff_blum
# Out:
# 0      -6.673301
# 1            NaN
# 2      -5.678758
# 3            NaN
# 4      -5.066813
# 6       1.717559
# 7      -5.680291
# 8      -3.714975
# 9      -3.714975
# 10           NaN
# 11           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21     -2.280222
# 22           NaN
# 23     -3.743899
# 24     -5.740717
# 25           NaN
# 26     -5.954008
# 27           NaN
# 28     -7.973748
# 29           NaN
# 30     -6.062326
# 31     -4.875599
#           ...
# 4730         NaN
# 4731         NaN
# 4732         NaN
# 4734         NaN
# 4735         NaN
# 4737         NaN
# 4741         NaN
# 4742    0.231387
# 4743         NaN
# 4744         NaN
# 4745         NaN
# 4746         NaN
# 4748         NaN
# 4749   -8.729605
# 4750         NaN
# 4751         NaN
# 4752   -6.973480
# 4753         NaN
# 4754   -6.203004
# 4755   -6.203004
# 4756         NaN
# ...

# %%
diff_rad
# Out:
# 0      -1.819000
# 1       0.472005
# 2       0.147492
# 3      -0.010200
# 4      -0.588625
# 6            NaN
# 7      -0.666356
# 8       0.073742
# 9       0.073742
# 10           NaN
# 11           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18     -0.070975
# 19      0.130002
# 20     -2.186593
# 21           NaN
# 22     -0.039041
# 23      3.019364
# 24      0.120331
# 25     -0.274734
# 26      0.430091
# 27           NaN
# 28      5.410117
# 29      0.002189
# 30      1.894412
# 31     -4.208214
#           ...
# 4730    0.001866
# 4731    0.103064
# 4732    0.088606
# 4734   -0.004558
# 4735    0.133094
# 4737    0.242896
# 4741    0.107286
# 4742    0.092221
# 4743   -0.024382
# 4744   -0.024382
# 4745   -0.088243
# 4746   -0.001032
# 4748   -0.486889
# 4749   -1.900160
# 4750         NaN
# 4751    2.108805
# 4752    2.936415
# 4753         NaN
# 4754    1.989857
# 4755    1.989857
# 4756         NaN
# ...

# %%
diff_temp = (gaia_exo['teff_val']-gaia_exo['st_teff'])/gaia_exo['teff_val']

# %%
diff_temp = diff_temp.to_frame()
diff_rad = diff_rad.to_frame()
diff_blum = diff_blum.to_frame()

# %%
diff =pd.concat([diff_blum, diff_rad, diff_temp], axis=1)

# %%
diff.columns = ['diff_in Bol_lum', 'diff_in_radius (in solar radius units)', 'diff_in_temp(in K)']

# %%
diff.hist(column = 'diff_in Bol_lum',bins=25, normed=True)
# Out:
# /home/chaithanya/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5451c2cc0>]],
#       dtype=object)

# %%
diff.hist(column = 'diff_in_radius (in solar radius units)',bins=50,normed=True)
# Out:
# /home/chaithanya/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc544faed30>]],
#       dtype=object)

# %%
diff.hist(column = 'diff_in_temp(in K)',bins=50, normed=True)
# Out:
# /home/chaithanya/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc544e56c18>]],
#       dtype=object)

# %%
diff_blum.max()
# Out:
# 0    24.365916
# dtype: float64

# %%
diff_blum.min()
# Out:
# 0   -185.922121
# dtype: float64

# %%
diff_rad.max()
# Out:
# 0    0.780465
# dtype: float64

# %%
diff_rad.min()
# Out:
# 0   -4.747593
# dtype: float64

# %%
diff_temp.max()
# Out:
# 0    0.181158
# dtype: float64

# %%
diff_temp.min()
# Out:
# 0   -5.654991
# dtype: float64
